# %%
import json
import os
from video_compressor import compress_folder

# %%
not_included_videos_dir = 'CADP/error-label-studio'
skipped_videos_dir = 'label-studio-result/skipped'
compress_folder_path = 'label-studio-result/second-attempt'

# %%
compress_folder(not_included_videos_dir, compress_folder_path)
# Out:
# MoviePy - Building video label-studio-result/second-attempt/vnuwuu_9kgM.mp4.
# MoviePy - Writing audio in vnuwuu_9kgMTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video label-studio-result/second-attempt/vnuwuu_9kgM.mp4
# MoviePy - Done !
# MoviePy - video ready label-studio-result/second-attempt/vnuwuu_9kgM.mp4
# Compression successful for CADP/error-label-studio/vnuwuu_9kgM.mp4
# MoviePy - Building video label-studio-result/second-attempt/qmsQ-obL1Z4.mp4.
# MoviePy - Writing audio in qmsQ-obL1Z4TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video label-studio-result/second-attempt/qmsQ-obL1Z4.mp4
# MoviePy - Done !
# MoviePy - video ready label-studio-result/second-attempt/qmsQ-obL1Z4.mp4
# Compression successful for CADP/error-label-studio/qmsQ-obL1Z4.mp4

# %%
compress_folder(skipped_videos_dir, compress_folder_path)
# Out:
# MoviePy - Building video label-studio-result/second-attempt/j4uIYeAFf1M.mp4.
# MoviePy - Writing audio in j4uIYeAFf1MTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video label-studio-result/second-attempt/j4uIYeAFf1M.mp4
# /home/pedro-antonio/Documentos/repos/projeto_mestrado_v2/myvenv/lib/python3.12/site-packages/moviepy/video/io/ffmpeg_reader.py:157: UserWarning: In file label-studio-result/skipped/j4uIYeAFf1M.mp4, 518400 bytes wanted but 0 bytes read at frame index 1145 (out of a total 1146 frames), at time 38.20/38.27 sec. Using the last valid frame instead.
#   warnings.warn(
# MoviePy - Done !
# MoviePy - video ready label-studio-result/second-attempt/j4uIYeAFf1M.mp4
# Compression successful for label-studio-result/skipped/j4uIYeAFf1M.mp4
# MoviePy - Building video label-studio-result/second-attempt/QVbVSDQGe_M.mp4.
# MoviePy - Writing audio in QVbVSDQGe_MTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# ...
